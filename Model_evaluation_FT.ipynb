# %%
from transformers import AutoTokenizer, T5ForConditionalGeneration
import torch
import pandas as pd
# Out:
# [2023-07-17 21:26:26,679] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 2023-07-17 21:26:31.674663: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-17 21:26:32.807599: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-17 21:26:33.564435: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-07-17 21:26:37.014060: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-07-17 21:26:37.014555: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-07-17 21:26:37.014567: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
model_name = "T5-fine-tuned-with-IMDB-wikisql"

if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name).to(device)
model.eval()
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 512)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 8)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-5): 5 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 8)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-5): 5 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=512, out_features=32128, bias=False)
# )

# %%
from datasets import Dataset

df = pd.read_csv('Training_set_IMDB/testing_set_no_target.csv')
df = df.sample(frac =1).reset_index(drop=True)
for index,row in df.iterrows():
    df.loc[index, 'Text'] = "Translate to SQL: " + row['Text']


df2 = pd.read_csv('Training_set_IMDB/testing_set_unseen_no_target.csv')
df2 = df2.sample(frac =1).reset_index(drop=True)
for index,row in df2.iterrows():
    df2.loc[index, 'Text'] = "Translate to SQL: " + row['Text']

test_set_seen = Dataset.from_pandas(df)
test_set_unseen = Dataset.from_pandas(df2)

# %%
test_set_seen.set_format(type = "torch")
test_set_unseen.set_format(type = "torch")

test_set_unseen["Text"][1]
# Out:
# 'Translate to SQL: How many movies in year 1975 and director_id 43411'

# %%
def convert_to_features(example_batch, padding = "max_length",input_max = 100, output_max = 170):
    inputs = tokenizer.batch_encode_plus(example_batch["Text"], max_length=input_max, is_split_into_words = False, padding='max_length', truncation=True, return_tensors = "pt")
    
    targets = tokenizer.batch_encode_plus(example_batch["SQL"], max_length=output_max, padding = "max_length",truncation = True)
    if padding == "max_length":
        targets["inputs_ids"] = [
            [(l if l != tokenizer.pad_token_id else -100) for l in target] for target in targets["input_ids"]
        ]
    
    inputs["labels"] = targets['input_ids']
    return inputs

def evaluate_peft_model(sample):
    outputs = model.generate(input_ids=sample["input_ids"].unsqueeze(0).cuda(), max_new_tokens = 200, top_p=0.9)
    prediction = tokenizer.decode(outputs[0].detach().cpu().numpy(), skip_special_tokens=True)
    label = np.where(sample['labels'] != -100, sample['labels'], tokenizer.pad_token_id)
    label = tokenizer.decode(label, skip_special_tokens=True)
    _ = execution_accuracy(prediction, label)
    return prediction, label

def execution_accuracy(prediction, label):
    try:
        
        cursor.execute(label)
        result_label = cursor.fetchall()
        all_executions_overall.append(1)
        try:
            cursor.execute(prediction)
            result_pred = cursor.fetchall()
            all_executions_accuracy.append(1)
            if len(result_label)>10:
                if len(result_label) == len(result_pred):
                    accurate_executions.append(1) 
            elif result_label == result_pred:
                accurate_executions.append(1)
            else:
                for_checking_label.append(label)
                for_checking_prediction.append(prediction)
                
        except:
            failed_executions.append(1)
            failed_predicted_SQL.append(prediction)
                
    except:
        failed_original_SQL.append(label)
    return None

# %%
import evaluate
import numpy as np
from tqdm import tqdm
import mysql.connector



connection = mysql.connector.connect(
    host="relational.fit.cvut.cz",
    user="guest",
    password="relational",
    database="imdb_ijs"
)
cursor = connection.cursor()



print("mapping both datasets")
tokenized_dataset = test_set_seen.map(convert_to_features, batched=True, num_proc=4)
tokenized_dataset_2 = test_set_unseen.map(convert_to_features, batched=True, num_proc=4)
print("mapped both dataset")
print("Documents we have: tokenizer_dataset for seen and tokenized_dataset_2 for unseen data")


print("\n\n Running executions for seen dataset")
all_executions_overall = []
failed_executions = []
all_executions_accuracy = []
accurate_executions = []
for_checking_label = []
for_checking_prediction = []
failed_original_SQL = []
failed_predicted_SQL = []



for sample in tokenized_dataset:
    p,l = evaluate_peft_model(sample)



print("All SQL runs:", len(all_executions_overall))
print("Model SQLs that failed: " len(failed_executions))
print(f"Execution rate: {len(all_executions_accuracy)/len(all_executions_overall)*100}%")
print(f"Execution rate: {100 - len(failed_executions)/len(all_executions_overall)*100}%")
print(f"Execution accuracy: {len(accurate_executions)/len(all_executions_accuracy)*100}%")

failed_original_sql_df = pd.DataFrame(failed_original_SQL)
failed_predicted_sql_df = pd.DataFrame(failed_predicted_SQL)
not_equals = pd.DataFrame({
    'Label':for_checking_label,
    'Prediction': for_checking_prediction
})

not_equals.to_csv("/home/toibazd/Data/Text2SQL/Training_set_IMDB/Not_equals_FT.csv", index = False)
failed_original_sql_df.to_csv("/home/toibazd/Data/Text2SQL/Training_set_IMDB/Failed_originals_FT.csv", index = False)
failed_predicted_sql_df.to_csv("/home/toibazd/Data/Text2SQL/Training_set_IMDB/Failed_predicted_FT.csv", index = False)
# Out:
# mapping both datasets
# Map (num_proc=4):   0%|          | 0/2315 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/2655 [00:00<?, ? examples/s]
# mapped both dataset
# Documents we have: tokenizer_dataset for seen and tokenized_dataset_2 for unseen data
#
#
#  Running executions for seen dataset
# all_executions_overall:  1
# all_executions_accuracy:  1
# accurate_executions:  1
# failed_executions:  0
# all_executions_overall:  2
# all_executions_accuracy:  2
# accurate_executions:  1
# failed_executions:  0
# all_executions_overall:  3
# all_executions_accuracy:  3
# accurate_executions:  2
# failed_executions:  0
# all_executions_overall:  4
# all_executions_accuracy:  4
# accurate_executions:  3
# failed_executions:  0
# all_executions_overall:  5
# all_executions_accuracy:  5
# accurate_executions:  4
# failed_executions:  0
# all_executions_overall:  6
# all_executions_accuracy:  6
# accurate_executions:  5
# failed_executions:  0
# all_executions_overall:  7
# all_executions_accuracy:  7
# accurate_executions:  6
# failed_executions:  0
# all_executions_overall:  8
# all_executions_accuracy:  8
# accurate_executions:  7
# failed_executions:  0
# except_1
# all_executions_overall:  8
# all_executions_accuracy:  8
# accurate_executions:  7
# failed_executions:  0
# all_executions_overall:  9
# all_executions_accuracy:  9
# accurate_executions:  8
# failed_executions:  0
# all_executions_overall:  10
# all_executions_accuracy:  10
# accurate_executions:  9
# failed_executions:  0
# all_executions_overall:  11
# all_executions_accuracy:  11
# accurate_executions:  10
# failed_executions:  0
# all_executions_overall:  12
# all_executions_accuracy:  12
# accurate_executions:  11
# failed_executions:  0
# except_1
# all_executions_overall:  12
# all_executions_accuracy:  12
# accurate_executions:  11
# failed_executions:  0
# all_executions_overall:  13
# all_executions_accuracy:  13
# accurate_executions:  12
# failed_executions:  0
# all_executions_overall:  14
# all_executions_accuracy:  14
# accurate_executions:  12
# failed_executions:  0
# all_executions_overall:  15
# all_executions_accuracy:  15
# accurate_executions:  13
# failed_executions:  0
# all_executions_overall:  16
# all_executions_accuracy:  16
# accurate_executions:  14
# failed_executions:  0
# all_executions_overall:  17
# all_executions_accuracy:  17
# accurate_executions:  15
# failed_executions:  0
# all_executions_overall:  18
# all_executions_accuracy:  18
# accurate_executions:  16
# failed_executions:  0
# all_executions_overall:  19
# all_executions_accuracy:  19
# accurate_executions:  17
# failed_executions:  0
# all_executions_overall:  20
# all_executions_accuracy:  20
# accurate_executions:  18
# failed_executions:  0
# all_executions_overall:  21
# all_executions_accuracy:  21
# accurate_executions:  19
# failed_executions:  0
# all_executions_overall:  22
# all_executions_accuracy:  22
# accurate_executions:  19
# failed_executions:  0
# except_1
# all_executions_overall:  22
# all_executions_accuracy:  22
# accurate_executions:  19
# failed_executions:  0
# all_executions_overall:  23
# all_executions_accuracy:  23
# accurate_executions:  20
# failed_executions:  0
# all_executions_overall:  24
# all_executions_accuracy:  24
# accurate_executions:  21
# failed_executions:  0
# all_executions_overall:  25
# all_executions_accuracy:  25
# accurate_executions:  22
# failed_executions:  0
# all_executions_overall:  26
# all_executions_accuracy:  26
# accurate_executions:  23
# failed_executions:  0
# all_executions_overall:  27
# all_executions_accuracy:  27
# accurate_executions:  24
# failed_executions:  0
# all_executions_overall:  28
# all_executions_accuracy:  28
# accurate_executions:  25
# failed_executions:  0
# all_executions_overall:  29
# all_executions_accuracy:  29
# accurate_executions:  26
# failed_executions:  0
# all_executions_overall:  30
# all_executions_accuracy:  30
# accurate_executions:  27
# failed_executions:  0
# all_executions_overall:  31
# all_executions_accuracy:  31
# accurate_executions:  28
# failed_executions:  0
# all_executions_overall:  32
# all_executions_accuracy:  32
# accurate_executions:  29
# failed_executions:  0
# except_1
# all_executions_overall:  32
# all_executions_accuracy:  32
# accurate_executions:  29
# failed_executions:  0
# all_executions_overall:  33
# all_executions_accuracy:  33
# accurate_executions:  30
# failed_executions:  0
# all_executions_overall:  34
# all_executions_accuracy:  34
# accurate_executions:  31
# failed_executions:  0
# all_executions_overall:  35
# all_executions_accuracy:  35
# accurate_executions:  32
# failed_executions:  0
# all_executions_overall:  36
# all_executions_accuracy:  36
# accurate_executions:  33
# failed_executions:  0
# all_executions_overall:  37
# all_executions_accuracy:  37
# accurate_executions:  33
# failed_executions:  0
# all_executions_overall:  38
# all_executions_accuracy:  38
# accurate_executions:  34
# failed_executions:  0
# all_executions_overall:  39
# all_executions_accuracy:  39
# accurate_executions:  35
# failed_executions:  0
# all_executions_overall:  40
# all_executions_accuracy:  40
# accurate_executions:  36
# failed_executions:  0
# all_executions_overall:  41
# all_executions_accuracy:  41
# accurate_executions:  37
# failed_executions:  0
# all_executions_overall:  42
# all_executions_accuracy:  42
# accurate_executions:  38
# failed_executions:  0
# all_executions_overall:  43
# all_executions_accuracy:  43
# accurate_executions:  39
# failed_executions:  0
# except_1
# all_executions_overall:  43
# all_executions_accuracy:  43
# accurate_executions:  39
# failed_executions:  0
# all_executions_overall:  44
# all_executions_accuracy:  44
# accurate_executions:  40
# failed_executions:  0
# except_1
# all_executions_overall:  44
# all_executions_accuracy:  44
# accurate_executions:  40
# failed_executions:  0
# all_executions_overall:  45
# all_executions_accuracy:  45
# accurate_executions:  41
# failed_executions:  0
# all_executions_overall:  46
# all_executions_accuracy:  46
# accurate_executions:  42
# failed_executions:  0
# except_1
# all_executions_overall:  46
# all_executions_accuracy:  46
# accurate_executions:  42
# failed_executions:  0
# all_executions_overall:  47
# all_executions_accuracy:  47
# accurate_executions:  43
# failed_executions:  0
# all_executions_overall:  48
# all_executions_accuracy:  48
# accurate_executions:  44
# failed_executions:  0
# except_1
# all_executions_overall:  48
# all_executions_accuracy:  48
# accurate_executions:  44
# failed_executions:  0
# all_executions_overall:  49
# all_executions_accuracy:  49
# accurate_executions:  45
# failed_executions:  0
# all_executions_overall:  50
# all_executions_accuracy:  50
# accurate_executions:  46
# failed_executions:  0
# all_executions_overall:  51
# all_executions_accuracy:  51
# accurate_executions:  47
# failed_executions:  0
# all_executions_overall:  52
# all_executions_accuracy:  52
# accurate_executions:  48
# failed_executions:  0
# all_executions_overall:  53
# all_executions_accuracy:  53
# accurate_executions:  49
# failed_executions:  0
# all_executions_overall:  54
# all_executions_accuracy:  54
# accurate_executions:  50
# failed_executions:  0
# all_executions_overall:  55
# all_executions_accuracy:  55
# accurate_executions:  51
# failed_executions:  0
# all_executions_overall:  56
# all_executions_accuracy:  56
# accurate_executions:  52
# failed_executions:  0
# all_executions_overall:  57
# all_executions_accuracy:  57
# accurate_executions:  53
# failed_executions:  0
# all_executions_overall:  58
# all_executions_accuracy:  58
# accurate_executions:  54
# failed_executions:  0
# all_executions_overall:  59
# all_executions_accuracy:  59
# accurate_executions:  54
# failed_executions:  0
# all_executions_overall:  60
# all_executions_accuracy:  60
# accurate_executions:  55
# failed_executions:  0
# all_executions_overall:  61
# all_executions_accuracy:  61
# accurate_executions:  56
# failed_executions:  0
# all_executions_overall:  62
# all_executions_accuracy:  62
# accurate_executions:  57
# failed_executions:  0
# all_executions_overall:  63
# all_executions_accuracy:  63
# accurate_executions:  58
# failed_executions:  0
# all_executions_overall:  64
# all_executions_accuracy:  64
# accurate_executions:  59
# failed_executions:  0
# all_executions_overall:  65
# all_executions_accuracy:  65
# accurate_executions:  60
# failed_executions:  0
# all_executions_overall:  66
# all_executions_accuracy:  66
# accurate_executions:  61
# failed_executions:  0
# all_executions_overall:  67
# all_executions_accuracy:  67
# accurate_executions:  61
# failed_executions:  0
# all_executions_overall:  68
# all_executions_accuracy:  68
# accurate_executions:  62
# failed_executions:  0
# all_executions_overall:  69
# all_executions_accuracy:  69
# accurate_executions:  63
# failed_executions:  0
# all_executions_overall:  70
# all_executions_accuracy:  70
# accurate_executions:  64
# failed_executions:  0
# all_executions_overall:  71
# all_executions_accuracy:  71
# accurate_executions:  65
# failed_executions:  0
# all_executions_overall:  72
# all_executions_accuracy:  72
# accurate_executions:  66
# failed_executions:  0
# all_executions_overall:  73
# all_executions_accuracy:  73
# accurate_executions:  67
# failed_executions:  0
# all_executions_overall:  74
# all_executions_accuracy:  74
# accurate_executions:  68
# failed_executions:  0
# all_executions_overall:  75
# all_executions_accuracy:  75
# accurate_executions:  69
# failed_executions:  0
# all_executions_overall:  76
# all_executions_accuracy:  76
# accurate_executions:  70
# failed_executions:  0
# all_executions_overall:  77
# all_executions_accuracy:  77
# accurate_executions:  71
# failed_executions:  0
# all_executions_overall:  78
# all_executions_accuracy:  78
# accurate_executions:  72
# failed_executions:  0
# all_executions_overall:  79
# all_executions_accuracy:  79
# accurate_executions:  73
# failed_executions:  0
# all_executions_overall:  80
# all_executions_accuracy:  80
# accurate_executions:  73
# failed_executions:  0
# except_1
# all_executions_overall:  80
# all_executions_accuracy:  80
# accurate_executions:  73
# failed_executions:  0
# all_executions_overall:  81
# all_executions_accuracy:  81
# accurate_executions:  74
# failed_executions:  0
# all_executions_overall:  82
# all_executions_accuracy:  82
# accurate_executions:  75
# failed_executions:  0
# except_1
# all_executions_overall:  82
# all_executions_accuracy:  82
# accurate_executions:  75
# failed_executions:  0
# all_executions_overall:  83
# all_executions_accuracy:  83
# accurate_executions:  76
# failed_executions:  0
# all_executions_overall:  84
# all_executions_accuracy:  84
# accurate_executions:  77
# failed_executions:  0
# all_executions_overall:  85
# all_executions_accuracy:  85
# accurate_executions:  78
# failed_executions:  0
# except_1
# all_executions_overall:  85
# all_executions_accuracy:  85
# accurate_executions:  78
# failed_executions:  0
# all_executions_overall:  86
# all_executions_accuracy:  86
# accurate_executions:  79
# failed_executions:  0
# all_executions_overall:  87
# all_executions_accuracy:  87
# accurate_executions:  80
# failed_executions:  0
# all_executions_overall:  88
# all_executions_accuracy:  88
# accurate_executions:  81
# failed_executions:  0
# all_executions_overall:  89
# all_executions_accuracy:  89
# accurate_executions:  82
# failed_executions:  0
# except_1
# all_executions_overall:  89
# all_executions_accuracy:  89
# accurate_executions:  82
# failed_executions:  0
# all_executions_overall:  90
# all_executions_accuracy:  90
# accurate_executions:  83
# failed_executions:  0
# except_1
# all_executions_overall:  90
# all_executions_accuracy:  90
# accurate_executions:  83
# failed_executions:  0
# all_executions_overall:  91
# all_executions_accuracy:  91
# accurate_executions:  84
# failed_executions:  0
# all_executions_overall:  92
# all_executions_accuracy:  92
# accurate_executions:  85
# failed_executions:  0
# all_executions_overall:  93
# all_executions_accuracy:  93
# accurate_executions:  86
# failed_executions:  0
# except_1
# all_executions_overall:  93
# all_executions_accuracy:  93
# accurate_executions:  86
# failed_executions:  0
# except_1
# all_executions_overall:  93
# all_executions_accuracy:  93
# accurate_executions:  86
# failed_executions:  0
# all_executions_overall:  94
# all_executions_accuracy:  94
# accurate_executions:  87
# failed_executions:  0
# all_executions_overall:  95
# all_executions_accuracy:  95
# accurate_executions:  88
# failed_executions:  0
# all_executions_overall:  96
# all_executions_accuracy:  96
# accurate_executions:  88
# failed_executions:  0
# all_executions_overall:  97
# all_executions_accuracy:  97
# accurate_executions:  89
# failed_executions:  0
# all_executions_overall:  98
# all_executions_accuracy:  98
# accurate_executions:  90
# failed_executions:  0
# all_executions_overall:  99
# all_executions_accuracy:  99
# accurate_executions:  91
# failed_executions:  0
# all_executions_overall:  100
# all_executions_accuracy:  100
# accurate_executions:  92
# failed_executions:  0
# all_executions_overall:  101
# all_executions_accuracy:  101
# accurate_executions:  93
# failed_executions:  0
# all_executions_overall:  102
# all_executions_accuracy:  102
# accurate_executions:  94
# failed_executions:  0
# all_executions_overall:  103
# all_executions_accuracy:  103
# accurate_executions:  95
# failed_executions:  0
# all_executions_overall:  104
# all_executions_accuracy:  104
# accurate_executions:  96
# failed_executions:  0
# all_executions_overall:  105
# all_executions_accuracy:  105
# accurate_executions:  97
# failed_executions:  0
# all_executions_overall:  106
# all_executions_accuracy:  106
# accurate_executions:  98
# failed_executions:  0
# all_executions_overall:  107
# all_executions_accuracy:  107
# accurate_executions:  99
# failed_executions:  0
# all_executions_overall:  108
# all_executions_accuracy:  108
# accurate_executions:  100
# failed_executions:  0
# all_executions_overall:  109
# all_executions_accuracy:  109
# accurate_executions:  101
# failed_executions:  0
# all_executions_overall:  110
# all_executions_accuracy:  110
# accurate_executions:  102
# failed_executions:  0
# all_executions_overall:  111
# all_executions_accuracy:  111
# accurate_executions:  103
# failed_executions:  0
# all_executions_overall:  112
# all_executions_accuracy:  112
# accurate_executions:  104
# failed_executions:  0
# all_executions_overall:  113
# all_executions_accuracy:  113
# accurate_executions:  105
# failed_executions:  0
# all_executions_overall:  114
# all_executions_accuracy:  114
# accurate_executions:  106
# failed_executions:  0
# all_executions_overall:  115
# all_executions_accuracy:  115
# accurate_executions:  107
# failed_executions:  0
# all_executions_overall:  116
# all_executions_accuracy:  116
# accurate_executions:  108
# failed_executions:  0
# all_executions_overall:  117
# all_executions_accuracy:  117
# accurate_executions:  108
# failed_executions:  0
# all_executions_overall:  118
# all_executions_accuracy:  118
# accurate_executions:  108
# failed_executions:  0
# all_executions_overall:  119
# all_executions_accuracy:  119
# accurate_executions:  109
# failed_executions:  0
# all_executions_overall:  120
# all_executions_accuracy:  120
# accurate_executions:  110
# failed_executions:  0
# all_executions_overall:  121
# all_executions_accuracy:  121
# accurate_executions:  111
# failed_executions:  0
# all_executions_overall:  122
# all_executions_accuracy:  122
# accurate_executions:  112
# failed_executions:  0
# all_executions_overall:  123
# all_executions_accuracy:  123
# accurate_executions:  113
# failed_executions:  0
# all_executions_overall:  124
# all_executions_accuracy:  124
# accurate_executions:  114
# failed_executions:  0
# all_executions_overall:  125
# all_executions_accuracy:  125
# accurate_executions:  115
# failed_executions:  0
# all_executions_overall:  126
# all_executions_accuracy:  126
# accurate_executions:  116
# failed_executions:  0
# all_executions_overall:  127
# all_executions_accuracy:  127
# accurate_executions:  117
# failed_executions:  0
# all_executions_overall:  128
# all_executions_accuracy:  128
# accurate_executions:  118
# failed_executions:  0
# all_executions_overall:  129
# all_executions_accuracy:  129
# accurate_executions:  119
# failed_executions:  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 38
#      33 failed_predicted_SQL = []
#      37 for sample in tokenized_dataset:
# ---> 38     p,l = evaluate_peft_model(sample)
#      39     print("all_executions_overall: ", len(all_executions_overall))
#      40     print("all_executions_accuracy: ",len(all_executions_accuracy))
#
# Cell In[6], line 14, in evaluate_peft_model(sample)
#      13 def evaluate_peft_model(sample):
# ---> 14     outputs = model.generate(input_ids=sample["input_ids"].unsqueeze(0).cuda(), max_new_tokens = 200, top_p=0.9)
#      15     prediction = tokenizer.decode(outputs[0].detach().cpu().numpy(), skip_special_tokens=True)
#      16     label = np.where(sample['labels'] != -100, sample['labels'], tokenizer.pad_token_id)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/generation/utils.py:1538, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, **kwargs)
#    1532         raise ValueError(
#    1533             "num_return_sequences has to be 1 when doing greedy search, "
#    1534             f"but is {generation_config.num_return_sequences}."
#    1535         )
#    1537     # 11. run greedy search
# -> 1538     return self.greedy_search(
#    1539         input_ids,
#    1540         logits_processor=logits_processor,
#    1541         stopping_criteria=stopping_criteria,
#    1542         pad_token_id=generation_config.pad_token_id,
#    1543         eos_token_id=generation_config.eos_token_id,
#    1544         output_scores=generation_config.output_scores,
#    1545         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1546         synced_gpus=synced_gpus,
#    1547         streamer=streamer,
#    1548         **model_kwargs,
#    1549     )
#    1551 elif is_contrastive_search_gen_mode:
#    1552     if generation_config.num_return_sequences > 1:
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/generation/utils.py:2362, in GenerationMixin.greedy_search(self, input_ids, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2359 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2361 # forward pass to get next token
# -> 2362 outputs = self(
#    2363     **model_inputs,
#    2364     return_dict=True,
#    2365     output_attentions=output_attentions,
#    2366     output_hidden_states=output_hidden_states,
#    2367 )
#    2369 if synced_gpus and this_peer_finished:
#    2370     continue  # don't waste resources running the code we don't need
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:1717, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1714         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1716 # Decode
# -> 1717 decoder_outputs = self.decoder(
#    1718     input_ids=decoder_input_ids,
#    1719     attention_mask=decoder_attention_mask,
#    1720     inputs_embeds=decoder_inputs_embeds,
#    1721     past_key_values=past_key_values,
#    1722     encoder_hidden_states=hidden_states,
#    1723     encoder_attention_mask=attention_mask,
#    1724     head_mask=decoder_head_mask,
#    1725     cross_attn_head_mask=cross_attn_head_mask,
#    1726     use_cache=use_cache,
#    1727     output_attentions=output_attentions,
#    1728     output_hidden_states=output_hidden_states,
#    1729     return_dict=return_dict,
#    1730 )
#    1732 sequence_output = decoder_outputs[0]
#    1734 # Set device for model parallelism
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:1094, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1081     layer_outputs = checkpoint(
#    1082         create_custom_forward(layer_module),
#    1083         hidden_states,
#    (...)
#    1091         None,  # past_key_value is always None with gradient checkpointing
#    1092     )
#    1093 else:
# -> 1094     layer_outputs = layer_module(
#    1095         hidden_states,
#    1096         attention_mask=extended_attention_mask,
#    1097         position_bias=position_bias,
#    1098         encoder_hidden_states=encoder_hidden_states,
#    1099         encoder_attention_mask=encoder_extended_attention_mask,
#    1100         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1101         layer_head_mask=layer_head_mask,
#    1102         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1103         past_key_value=past_key_value,
#    1104         use_cache=use_cache,
#    1105         output_attentions=output_attentions,
#    1106     )
#    1108 # layer_outputs is a tuple with:
#    1109 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1110 if use_cache is False:
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:694, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     691 else:
#     692     self_attn_past_key_value, cross_attn_past_key_value = None, None
# --> 694 self_attention_outputs = self.layer[0](
#     695     hidden_states,
#     696     attention_mask=attention_mask,
#     697     position_bias=position_bias,
#     698     layer_head_mask=layer_head_mask,
#     699     past_key_value=self_attn_past_key_value,
#     700     use_cache=use_cache,
#     701     output_attentions=output_attentions,
#     702 )
#     703 hidden_states, present_key_value_state = self_attention_outputs[:2]
#     704 attention_outputs = self_attention_outputs[2:]  # Keep self-attention outputs and relative position weights
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:601, in T5LayerSelfAttention.forward(self, hidden_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, output_attentions)
#     590 def forward(
#     591     self,
#     592     hidden_states,
#    (...)
#     598     output_attentions=False,
#     599 ):
#     600     normed_hidden_states = self.layer_norm(hidden_states)
# --> 601     attention_output = self.SelfAttention(
#     602         normed_hidden_states,
#     603         mask=attention_mask,
#     604         position_bias=position_bias,
#     605         layer_head_mask=layer_head_mask,
#     606         past_key_value=past_key_value,
#     607         use_cache=use_cache,
#     608         output_attentions=output_attentions,
#     609     )
#     610     hidden_states = hidden_states + self.dropout(attention_output[0])
#     611     outputs = (hidden_states,) + attention_output[1:]  # add attentions if we output them
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:520, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     517     return hidden_states
#     519 # get query states
# --> 520 query_states = shape(self.q(hidden_states))  # (batch_size, n_heads, seq_length, dim_per_head)
#     522 # get key/value states
#     523 key_states = project(
#     524     hidden_states, self.k, key_value_states, past_key_value[0] if past_key_value is not None else None
#     525 )
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
print("\n \n Running evaluation on unseen data")
all_executions_overall = []
failed_executions = []
all_executions_accuracy = []
accurate_executions = []
for_checking_label = []
for_checking_prediction = []
failed_original_SQL = []
failed_predicted_SQL = []


for sample in tokenized_dataset_2:
    p,l = evaluate_peft_model(sample)

    
    
print("All SQL runs:", len(all_executions_overall))
print("Model SQLs that failed: " len(failed_executions))
print(f"Execution rate: {len(all_executions_accuracy)/len(all_executions_overall)*100}%")
print(f"Execution rate: {100 - len(failed_executions)/len(all_executions_overall)*100}%")
print(f"Execution accuracy: {len(accurate_executions)/len(all_executions_accuracy)*100}%")
# Out:
#
#  Running evaluation on unseen data
# all_executions_overall:  0
# all_executions_accuracy:  0
# accurate_executions:  0
# failed_executions:  0
# except_2
# all_executions_overall:  1
# all_executions_accuracy:  0
# accurate_executions:  0
# failed_executions:  1
# except_2
# all_executions_overall:  2
# all_executions_accuracy:  0
# accurate_executions:  0
# failed_executions:  2
# except_2
# all_executions_overall:  3
# all_executions_accuracy:  0
# accurate_executions:  0
# failed_executions:  3
# except_1
# all_executions_overall:  3
# all_executions_accuracy:  0
# accurate_executions:  0
# failed_executions:  3
# except_1
# all_executions_overall:  3
# all_executions_accuracy:  0
# accurate_executions:  0
# failed_executions:  3
# except_1
# all_executions_overall:  3
# all_executions_accuracy:  0
# accurate_executions:  0
# failed_executions:  3
# except_1
# all_executions_overall:  3
# all_executions_accuracy:  0
# accurate_executions:  0
# failed_executions:  3
# except_1
# all_executions_overall:  3
# all_executions_accuracy:  0
# accurate_executions:  0
# failed_executions:  3
# except_1
# all_executions_overall:  3
# all_executions_accuracy:  0
# accurate_executions:  0
# failed_executions:  3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 16
#      13 print("failed_executions: ", len(failed_executions))
#      15 for sample in tokenized_dataset_2:
# ---> 16     p,l = evaluate_peft_model(sample)
#      17     print("all_executions_overall: ", len(all_executions_overall))
#      18     print("all_executions_accuracy: ",len(all_executions_accuracy))
#
# Cell In[17], line 14, in evaluate_peft_model(sample)
#      13 def evaluate_peft_model(sample):
# ---> 14     outputs = model.generate(input_ids=sample["input_ids"].unsqueeze(0).cuda(), max_new_tokens = 200, top_p=0.9)
#      15     prediction = tokenizer.decode(outputs[0].detach().cpu().numpy(), skip_special_tokens=True)
#      16     label = np.where(sample['labels'] != -100, sample['labels'], tokenizer.pad_token_id)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/generation/utils.py:1538, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, **kwargs)
#    1532         raise ValueError(
#    1533             "num_return_sequences has to be 1 when doing greedy search, "
#    1534             f"but is {generation_config.num_return_sequences}."
#    1535         )
#    1537     # 11. run greedy search
# -> 1538     return self.greedy_search(
#    1539         input_ids,
#    1540         logits_processor=logits_processor,
#    1541         stopping_criteria=stopping_criteria,
#    1542         pad_token_id=generation_config.pad_token_id,
#    1543         eos_token_id=generation_config.eos_token_id,
#    1544         output_scores=generation_config.output_scores,
#    1545         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1546         synced_gpus=synced_gpus,
#    1547         streamer=streamer,
#    1548         **model_kwargs,
#    1549     )
#    1551 elif is_contrastive_search_gen_mode:
#    1552     if generation_config.num_return_sequences > 1:
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/generation/utils.py:2362, in GenerationMixin.greedy_search(self, input_ids, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2359 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2361 # forward pass to get next token
# -> 2362 outputs = self(
#    2363     **model_inputs,
#    2364     return_dict=True,
#    2365     output_attentions=output_attentions,
#    2366     output_hidden_states=output_hidden_states,
#    2367 )
#    2369 if synced_gpus and this_peer_finished:
#    2370     continue  # don't waste resources running the code we don't need
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:1717, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1714         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1716 # Decode
# -> 1717 decoder_outputs = self.decoder(
#    1718     input_ids=decoder_input_ids,
#    1719     attention_mask=decoder_attention_mask,
#    1720     inputs_embeds=decoder_inputs_embeds,
#    1721     past_key_values=past_key_values,
#    1722     encoder_hidden_states=hidden_states,
#    1723     encoder_attention_mask=attention_mask,
#    1724     head_mask=decoder_head_mask,
#    1725     cross_attn_head_mask=cross_attn_head_mask,
#    1726     use_cache=use_cache,
#    1727     output_attentions=output_attentions,
#    1728     output_hidden_states=output_hidden_states,
#    1729     return_dict=return_dict,
#    1730 )
#    1732 sequence_output = decoder_outputs[0]
#    1734 # Set device for model parallelism
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:1094, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1081     layer_outputs = checkpoint(
#    1082         create_custom_forward(layer_module),
#    1083         hidden_states,
#    (...)
#    1091         None,  # past_key_value is always None with gradient checkpointing
#    1092     )
#    1093 else:
# -> 1094     layer_outputs = layer_module(
#    1095         hidden_states,
#    1096         attention_mask=extended_attention_mask,
#    1097         position_bias=position_bias,
#    1098         encoder_hidden_states=encoder_hidden_states,
#    1099         encoder_attention_mask=encoder_extended_attention_mask,
#    1100         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1101         layer_head_mask=layer_head_mask,
#    1102         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1103         past_key_value=past_key_value,
#    1104         use_cache=use_cache,
#    1105         output_attentions=output_attentions,
#    1106     )
#    1108 # layer_outputs is a tuple with:
#    1109 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1110 if use_cache is False:
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:754, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     751     attention_outputs = attention_outputs + cross_attention_outputs[2:]
#     753 # Apply Feed Forward layer
# --> 754 hidden_states = self.layer[-1](hidden_states)
#     756 # clamp inf values to enable fp16 training
#     757 if hidden_states.dtype == torch.float16:
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:342, in T5LayerFF.forward(self, hidden_states)
#     341 def forward(self, hidden_states):
# --> 342     forwarded_states = self.layer_norm(hidden_states)
#     343     forwarded_states = self.DenseReluDense(forwarded_states)
#     344     hidden_states = hidden_states + self.dropout(forwarded_states)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:254, in T5LayerNorm.forward(self, hidden_states)
#     247 def forward(self, hidden_states):
#     248     # T5 uses a layer_norm which only scales and doesn't shift, which is also known as Root Mean
#     249     # Square Layer Normalization https://arxiv.org/abs/1910.07467 thus varience is calculated
#     250     # w/o mean and there is no bias. Additionally we want to make sure that the accumulation for
#     251     # half-precision inputs is done in fp32
#     253     variance = hidden_states.to(torch.float32).pow(2).mean(-1, keepdim=True)
# --> 254     hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
#     256     # convert into half-precision if necessary
#     257     if self.weight.dtype in [torch.float16, torch.bfloat16]:
#
# KeyboardInterrupt:
